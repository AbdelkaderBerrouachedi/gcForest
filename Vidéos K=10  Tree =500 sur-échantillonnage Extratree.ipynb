# %%
#les imports 
import numpy as np
import pandas as pd
#from pyspark.mllib.stat import Statistics 
from math import sqrt 
from pprint import pprint
from numpy import array
import os
import os.path as osp
import pickle

# %%
df = pd.read_excel("videos.xlsx")

# %%
#comptage des valeurs
print('comptage des valeurs  ValueToPredict : ')
print('-------------------------------------- ')

print(df['ValueToPredict'].value_counts())
# Out:
# comptage des valeurs  ValueToPredict :
# --------------------------------------
# 0      43659
# 25       603
# 50       327
# 33       204
# 66       199
# 40       103
# 20        97
# 60        77
# 75        55
# 100       52
# Name: ValueToPredict, dtype: int64

# %%
# Filtre les classes minoritaire
c20=df[df.ValueToPredict == 20 ]   # 97
#c25=df[df.ValueToPredict == 25 ]   # 603
c50=df[df.ValueToPredict == 50 ]   # 327
c33=df[df.ValueToPredict == 33 ]   # 204
c66=df[df.ValueToPredict == 66 ]   # 199
c40=df[df.ValueToPredict == 40 ]   # 103
c60=df[df.ValueToPredict == 60 ]   # 77
c75=df[df.ValueToPredict == 75]    # 55
c100=df[df.ValueToPredict == 100]  # 52

# %%
# Préparation des classes Minoritaire
c20 = pd.concat([c20,c20,c20,c20,c20,c20], ignore_index=True)     # Classe 20 duppliquer en 6 fois 97 * 6 = 582
c60 = pd.concat([c60,c60,c60,c60,c60,c60,c60], ignore_index=True) # Classe 60 duppliquer en 7 fois 77 * 7 = 539
c75 = pd.concat([c75,c75,c75,c75,c75,c75,c75,c75,c75,c75], ignore_index=True) # Classe 75 duppliquer en 10 fois 55 * 10 =550
c100 = pd.concat([c100,c100,c100,c100,c100,c100,c100,c100,c100,c100], ignore_index=True) # Classe 100 duppliquer en 10 fois 52 * 10 = 520
c50 = pd.concat([c50,c50], ignore_index=True)  # Classe 50 duppliquer en 2 fois 327 * 2 = 654
c33 = pd.concat([c33,c33,c33], ignore_index=True)   # Classe 33 duppliquer en 3 fois 204 * 3 = 612
c66 = pd.concat([c66,c66,c66], ignore_index=True)   # Classe 66 duppliquer en 3 fois 199 * 3 = 597
c40 = pd.concat([c40,c40,c40,c40,c40,c40], ignore_index=True)   # Classe 40 duppliquer en 6 fois 103 * 6 = 618

# %%
print c20.shape
print c60.shape
print c75.shape
print c100.shape
print c50.shape
print c33.shape
print c66.shape
print c40.shape
# Out:
# (582, 378)
# (539, 378)
# (550, 378)
# (520, 378)
# (654, 378)
# (612, 378)
# (597, 378)
# (618, 378)

# %%
c_ech = pd.concat([c20,c60,c75,c100,c50,c33,c40,c66], ignore_index=True)  #  (4672, 378)

# %%
c_ech.shape
# Out:
# (4672, 378)

# %%
df_ech = pd.concat([df, c_ech], ignore_index=True) # (45376 + 4672) = (50048, 378)

# %%
df_ech.shape  # Dataset apres sur-échantionnage
# Out:
# (50048, 378)

# %%
df.shape
# Out:
# (45376, 378)

# %%
print(df_ech['ValueToPredict'].value_counts())  # statistique de la nouvelle dataset
# Out:
# 0      43659
# 50       981
# 33       816
# 66       796
# 40       721
# 20       679
# 60       616
# 75       605
# 25       603
# 100      572
# Name: ValueToPredict, dtype: int64

# %%
#df = df.values

# %%
df_ech = df_ech.values  # converter en array

# %%
import argparse
import numpy as np
import sys
import pickle
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
sys.path.insert(0, "lib")

from gcforest.gcforest import GCForest
#from gcforest.utils.config_utils import load_json

# %%
from gcforest.gcforest import GCForest
from gcforest.utils.config_utils import load_json
# K-Fold = 5   n_estimators = 10
config = load_json("./examples/videoExtrat.json")
gc = GCForest(config)

# %%
from sklearn.cross_validation import train_test_split
 
X = df_ech[:,0:377]
y = df_ech[:,377]

X_train,X_test,y_train,y_test = train_test_split(X, y, test_size=0.33, random_state=42)
# Out:
# /home/kader/anaconda3/envs/py27/lib/python2.7/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
y.shape
# Out:
# (50048,)

# %%
X.shape
# Out:
# (50048, 377)

# %%
# Nombre de classe - y_train
len(np.unique(y_train))
# Out:
# 10

# %%
# Plot normalized confusion matrix
import itertools
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm, datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

class_names=['0','50','33','66','40','20','60','75','25','100']

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

   # print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
 # If the model you use cost too much memory for you.
    # You can use these methods to force gcforest not keeping model in memory
    # gc.set_keep_model_in_mem(False), default is TRUE.

#(X_train, y_train), (X_test, y_test) = df.
#X_train, y_train = X_train[:28691], y_train[:28691]
#X_train = X_train[:, np.newaxis,:]
#X_test = X_test[:, np.newaxis,:]

# %%
from time import time
t0 = time()

X_train_enc = gc.fit_transform(X_train, y_train)
    # X_enc is the concatenated predict_proba result of each estimators of the last layer of the GCForest model
    # X_enc.shape =
    #   (n_datas, n_estimators * n_classes): If cascade is provided
    #   (n_datas, n_estimators * n_classes, dimX, dimY): If only finegrained part is provided
    # You can also pass X_test, y_test to fit_transform method, then the accracy on test data will be logged when training.
#X_train_enc, X_test_enc = gc.fit_transform(X_train, y_train, X_test=X_test, y_test=y_test)
    # WARNING: if you set gc.set_keep_model_in_mem(True), you would have to use
    # gc.fit_transform(X_train, y_train, X_test=X_test, y_test=y_test) to evaluate your model.
    

tt = time() - t0
print ("Compte fait en ",format(round(tt,3))," seconds")
# Out:
# [ 2018-02-21 14:09:05,323][cascade_classifier.fit_transform] X_groups_train.shape=[(33532, 377)],y_train.shape=(33532,),X_groups_test.shape=no_test,y_test.shape=no_test
# [ 2018-02-21 14:09:05,390][cascade_classifier.fit_transform] group_dims=[377]
# [ 2018-02-21 14:09:05,391][cascade_classifier.fit_transform] group_starts=[0]
# [ 2018-02-21 14:09:05,392][cascade_classifier.fit_transform] group_ends=[377]
# [ 2018-02-21 14:09:05,394][cascade_classifier.fit_transform] X_train.shape=(33532, 377),X_test.shape=(0, 377)
# [ 2018-02-21 14:09:05,455][cascade_classifier.fit_transform] [layer=0] look_indexs=[0], X_cur_train.shape=(33532, 377), X_cur_test.shape=(0, 377)
# [ 2018-02-21 14:09:42,492][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_0.predict)=86.06%
# [ 2018-02-21 14:10:24,259][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_1.predict)=85.96%
# [ 2018-02-21 14:11:04,906][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_2.predict)=85.87%
# [ 2018-02-21 14:11:44,041][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_3.predict)=86.29%
# [ 2018-02-21 14:12:23,480][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_4.predict)=86.20%
# [ 2018-02-21 14:13:02,864][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_5.predict)=85.96%
# [ 2018-02-21 14:13:41,528][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_6.predict)=86.22%
# [ 2018-02-21 14:14:24,848][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_7.predict)=86.03%
# [ 2018-02-21 14:15:05,489][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_8.predict)=85.88%
# [ 2018-02-21 14:15:47,426][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_9.predict)=85.91%
# [ 2018-02-21 14:15:47,432][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_cv.predict)=86.04%
# [ 2018-02-21 14:15:47,438][cascade_classifier.calc_accuracy] Accuracy(layer_0 - train.classifier_average)=86.04%
# [ 2018-02-21 14:15:47,506][cascade_classifier.fit_transform] [layer=1] look_indexs=[0], X_cur_train.shape=(33532, 387), X_cur_test.shape=(0, 387)
# [ 2018-02-21 14:16:33,190][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_0.predict)=86.45%
# [ 2018-02-21 14:17:18,556][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_1.predict)=86.08%
# [ 2018-02-21 14:18:07,466][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_2.predict)=86.20%
# [ 2018-02-21 14:18:54,886][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_3.predict)=86.26%
# [ 2018-02-21 14:19:44,866][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_4.predict)=86.35%
# [ 2018-02-21 14:20:26,757][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_5.predict)=86.43%
# [ 2018-02-21 14:21:06,832][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_6.predict)=86.67%
# [ 2018-02-21 14:21:46,883][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_7.predict)=86.60%
# [ 2018-02-21 14:22:26,833][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_8.predict)=86.41%
# [ 2018-02-21 14:23:07,255][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_9.predict)=86.41%
# [ 2018-02-21 14:23:07,262][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_cv.predict)=86.39%
# [ 2018-02-21 14:23:07,269][cascade_classifier.calc_accuracy] Accuracy(layer_1 - train.classifier_average)=86.39%
# [ 2018-02-21 14:23:07,349][cascade_classifier.fit_transform] [layer=2] look_indexs=[0], X_cur_train.shape=(33532, 387), X_cur_test.shape=(0, 387)
# [ 2018-02-21 14:23:47,700][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_0.predict)=86.60%
# [ 2018-02-21 14:24:27,737][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_1.predict)=86.56%
# [ 2018-02-21 14:25:08,041][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_2.predict)=86.50%
# [ 2018-02-21 14:25:49,958][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_3.predict)=86.35%
# [ 2018-02-21 14:26:30,938][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_4.predict)=86.53%
# [ 2018-02-21 14:27:11,109][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_5.predict)=86.29%
# [ 2018-02-21 14:27:51,470][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_6.predict)=86.40%
# [ 2018-02-21 14:28:32,673][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_7.predict)=86.54%
# [ 2018-02-21 14:29:14,084][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_8.predict)=86.74%
# [ 2018-02-21 14:29:57,303][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_9.predict)=86.47%
# [ 2018-02-21 14:29:57,344][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_cv.predict)=86.50%
# [ 2018-02-21 14:29:57,959][cascade_classifier.calc_accuracy] Accuracy(layer_2 - train.classifier_average)=86.50%
# [ 2018-02-21 14:29:58,273][cascade_classifier.fit_transform] [layer=3] look_indexs=[0], X_cur_train.shape=(33532, 387), X_cur_test.shape=(0, 387)
# [ 2018-02-21 14:30:45,095][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_0.predict)=86.48%
# [ 2018-02-21 14:31:27,361][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_1.predict)=86.29%
# [ 2018-02-21 14:32:10,460][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_2.predict)=86.44%
# [ 2018-02-21 14:32:59,184][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_3.predict)=86.56%
# [ 2018-02-21 14:34:22,106][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_4.predict)=86.32%
# [ 2018-02-21 14:35:03,393][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_5.predict)=86.37%
# [ 2018-02-21 14:35:43,729][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_6.predict)=86.46%
# [ 2018-02-21 14:36:25,686][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_7.predict)=86.60%
# [ 2018-02-21 14:37:07,410][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_8.predict)=86.95%
# [ 2018-02-21 14:37:48,715][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_9.predict)=86.68%
# [ 2018-02-21 14:37:48,722][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_cv.predict)=86.51%
# [ 2018-02-21 14:37:48,798][cascade_classifier.calc_accuracy] Accuracy(layer_3 - train.classifier_average)=86.51%
# [ 2018-02-21 14:37:48,937][cascade_classifier.fit_transform] [layer=4] look_indexs=[0], X_cur_train.shape=(33532, 387), X_cur_test.shape=(0, 387)
# [ 2018-02-21 14:38:44,353][kfold_wrapper.log_eval_metrics] Accuracy(layer_4 - estimator_0 - 10_folds.train_0.predict)=86.62%
# [ 2018-02-21 14:39:33,271][kfold_wrapper.log_eval_metrics] Accuracy(layer_4 - estimator_0 - 10_folds.train_1.predict)=86.53%
# [ 2018-02-21 14:40:14,780][kfold_wrapper.log_eval_metrics] Accuracy(layer_4 - estimator_0 - 10_folds.train_2.predict)=86.62%
# [ 2018-02-21 14:40:59,807][kfold_wrapper.log_eval_metrics] Accuracy(layer_4 - estimator_0 - 10_folds.train_3.predict)=86.38%
# [ 2018-02-21 14:41:43,880][kfold_wrapper.log_eval_metrics] Accuracy(layer_4 - estimator_0 - 10_folds.train_4.predict)=86.23%
# [ 2018-02-21 14:42:28,598][kfold_wrapper.log_eval_metrics] Accuracy(layer_4 - estimator_0 - 10_folds.train_5.predict)=86.64%
# [ 2018-02-21 14:43:12,644][kfold_wrapper.log_eval_metrics] Accuracy(layer_4 - estimator_0 - 10_folds.train_6.predict)=86.34%
# [ 2018-02-21 14:43:58,315][kfold_wrapper.log_eval_metrics] Accuracy(layer_4 - estimator_0 - 10_folds.train_7.predict)=86.42%
# [ 2018-02-21 14:44:41,224][kfold_wrapper.log_eval_metrics] Accuracy(layer_4 - estimator_0 - 10_folds.train_8.predict)=86.56%
# [ 2018-02-21 14:45:22,104][kfold_wrapper.log_eval_metrics] Accuracy(layer_4 - estimator_0 - 10_folds.train_9.predict)=86.68%
# [ 2018-02-21 14:45:22,125][kfold_wrapper.log_eval_metrics] Accuracy(layer_4 - estimator_0 - 10_folds.train_cv.predict)=86.50%
# [ 2018-02-21 14:45:22,178][cascade_classifier.calc_accuracy] Accuracy(layer_4 - train.classifier_average)=86.50%
# [ 2018-02-21 14:45:22,303][cascade_classifier.fit_transform] [layer=5] look_indexs=[0], X_cur_train.shape=(33532, 387), X_cur_test.shape=(0, 387)
# [ 2018-02-21 14:46:03,181][kfold_wrapper.log_eval_metrics] Accuracy(layer_5 - estimator_0 - 10_folds.train_0.predict)=86.42%
# [ 2018-02-21 14:46:44,262][kfold_wrapper.log_eval_metrics] Accuracy(layer_5 - estimator_0 - 10_folds.train_1.predict)=86.50%
# [ 2018-02-21 14:47:25,466][kfold_wrapper.log_eval_metrics] Accuracy(layer_5 - estimator_0 - 10_folds.train_2.predict)=86.65%
# [ 2018-02-21 14:48:08,380][kfold_wrapper.log_eval_metrics] Accuracy(layer_5 - estimator_0 - 10_folds.train_3.predict)=86.56%
# [ 2018-02-21 14:48:50,107][kfold_wrapper.log_eval_metrics] Accuracy(layer_5 - estimator_0 - 10_folds.train_4.predict)=86.44%
# [ 2018-02-21 14:49:31,323][kfold_wrapper.log_eval_metrics] Accuracy(layer_5 - estimator_0 - 10_folds.train_5.predict)=86.52%
# [ 2018-02-21 14:50:13,146][kfold_wrapper.log_eval_metrics] Accuracy(layer_5 - estimator_0 - 10_folds.train_6.predict)=86.40%

# %%
from time import time
t0 = time()

y_pred = gc.predict(X_test)
acc = accuracy_score(y_test, y_pred)
print("Test Accuracy of GcForest = {:.2f} %".format(acc * 100))

tt = time() - t0
print ("Compte fait en ",format(round(tt,3))," seconds")
# Out:
# [ 2018-02-20 18:18:58,755][cascade_classifier.transform] X_groups_test.shape=[(16516, 377)]
# [ 2018-02-20 18:18:58,790][cascade_classifier.transform] group_dims=[377]
# [ 2018-02-20 18:18:58,791][cascade_classifier.transform] X_test.shape=(16516, 377)
# [ 2018-02-20 18:18:58,820][cascade_classifier.transform] [layer=0] look_indexs=[0], X_cur_test.shape=(16516, 377)
# [ 2018-02-20 18:19:01,672][cascade_classifier.transform] [layer=1] look_indexs=[0], X_cur_test.shape=(16516, 417)
# [ 2018-02-20 18:19:04,392][cascade_classifier.transform] [layer=2] look_indexs=[0], X_cur_test.shape=(16516, 417)
# [ 2018-02-20 18:19:07,191][cascade_classifier.transform] [layer=3] look_indexs=[0], X_cur_test.shape=(16516, 417)
# [ 2018-02-20 18:19:09,860][cascade_classifier.transform] [layer=4] look_indexs=[0], X_cur_test.shape=(16516, 417)
# [ 2018-02-20 18:19:12,565][cascade_classifier.transform] [layer=5] look_indexs=[0], X_cur_test.shape=(16516, 417)
# Test Accuracy of GcForest = 87.06 %
# ('Compte fait en ', '16.487', ' seconds')

# %%
# Compute confusion matrix
cnf_matrix = confusion_matrix(y_test, y_pred)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure(figsize=(7, 7))
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix, without normalization')

# Plot normalized confusion matrix
plt.figure(figsize=(7, 7))
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# /home/kader/anaconda3/envs/py27/lib/python2.7/site-packages/ipykernel_launcher.py:20: RuntimeWarning: invalid value encountered in divide
# Normalized confusion matrix

# %%
X_train.shape
# Out:
# (33532, 377)

# %%
y_train.shape
# Out:
# (33532,)

# %%
from time import time
t0 = time()

from sklearn import linear_model, datasets
from sklearn.linear_model import LogisticRegression
# You can try passing X_enc to another classfier on top of gcForest.e.g. xgboost/RF.
X_test_enc = gc.transform(X_test)
X_train_enc = X_train_enc.reshape((X_train_enc.shape[0], -1))
X_test_enc = X_test_enc.reshape((X_test_enc.shape[0], -1))
X_train_origin = X_train.reshape((X_train.shape[0], -1))
X_test_origin = X_test.reshape((X_test.shape[0], -1))
X_train_enc = np.hstack((X_train_origin, X_train_enc))
X_test_enc = np.hstack((X_test_origin, X_test_enc))
print("X_train_enc.shape={}, X_test_enc.shape={}".format(X_train_enc.shape, X_test_enc.shape))
clf = clf = ExtraTreesClassifier(n_estimators=500, max_depth=None, n_jobs=-1)
clf.fit(X_train_enc, y_train)
y_pred = clf.predict(X_test_enc)
acc = accuracy_score(y_test, y_pred)
print("Test Accuracy of Other classifier using gcforest's X_encode = {:.6f} %".format(acc * 100))  

tt = time() - t0
print ("Compte fait en ",format(round(tt,3))," seconds")
# Out:
# X_train_enc.shape=(33532, 417), X_test_enc.shape=(16516, 417)
# Test Accuracy of Other classifier using gcforest's X_encode = 96.803100 %
# ('Compte fait en ', '399.147', ' seconds')

# %%
# Compute confusion matrix
cnf_matrix = confusion_matrix(y_test, y_pred)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure(figsize=(7, 7))
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix, without normalization')

# Plot normalized confusion matrix
plt.figure(figsize=(7, 7))
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# Normalized confusion matrix

# %%
X_test_enc.shape
# Out:
# (16516, 417)

# %%
X_train_enc.shape
# Out:
# (33532, 417)

# %%
from time import time
t0 = time()

from sklearn.ensemble import ExtraTreesClassifier
print("X_train.shape={}, X_test.shape={}".format(X_train.shape, X_test.shape))
clf = clf = ExtraTreesClassifier(n_estimators=500, max_depth=None, n_jobs=-1)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
acc = accuracy_score(y_test, y_pred)
print("Test Accuracy of ExtraTreesClassifier = {:.6f} %".format(acc * 100)) 

tt = time() - t0
print ("Compte fait en ",format(round(tt,3))," seconds")
# Out:
# X_train_enc.shape=(33532, 417), X_test_enc.shape=(16516, 417)
# Test Accuracy of ExtraTreesClassifier using gcforest's X_encode = 96.730443 %
# ('Compte fait en ', '2.47', ' seconds')

# %%
# Compute confusion matrix
cnf_matrix = confusion_matrix(y_test, y_pred)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure(figsize=(7, 7))
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix, without normalization')

# Plot normalized confusion matrix
plt.figure(figsize=(7, 7))
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# Normalized confusion matrix
